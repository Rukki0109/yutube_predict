# %%
import os, sys
sys.path.append(r"C:\Users\Owner\youtube")   # 親フォルダをPATHに追加
os.environ["YT_API_KEY"] ="AIzaSyApavwxqaBLkNyK65iHdgmUf9eX5CsYrmI"

from yt_trendlab import run_all
model, df_result, metrics, imp_top = run_all(
    xlsx_path="youtube_dataset_20250829.xlsx",
    cutoff="2025-07-01",
    tfidf_max_features=300
)
print(metrics)        # {'rmse_log': ..., 'rmse_raw': ...}
display(imp_top)      # 重要度TOP30
display(df_result.head(10))  # 直近サンプルの予測と誤差
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 os.environ["YT_API_KEY"] ="AIzaSyApavwxqaBLkNyK65iHdgmUf9eX5CsYrmI"
#       5 from yt_trendlab import run_all
# ----> 6 model, df_result, metrics, imp_top = run_all(
#       7     xlsx_path="youtube_dataset_20250829.xlsx",
#       8     cutoff="2025-07-01",
#       9     tfidf_max_features=300
#      10 )
#      11 print(metrics)        # {'rmse_log': ..., 'rmse_raw': ...}
#      12 display(imp_top)      # 重要度TOP30
#
# File ~\youtube\yt_trendlab\pipeline.py:37, in run_all(xlsx_path, cutoff, tfidf_max_features)
#      34 df = df[df["duration_seconds"] > 60].copy()
#      36 # 2) thumbnail
# ---> 37 df = _ensure_thumbnail_features(df)
#      39 # 3) time
#      40 df = _time_features(df)
#
# File ~\youtube\yt_trendlab\pipeline.py:14, in _ensure_thumbnail_features(df)
# ...

# %%
import yt_trendlab, importlib, inspect
print("run_all found at:", inspect.getsourcefile(yt_trendlab.run_all))
print("has verbose arg?:", "verbose" in inspect.signature(yt_trendlab.run_all).parameters)
# Out:
# run_all found at: C:\Users\Owner\youtube\yt_trendlab\pipeline.py
# has verbose arg?: False
